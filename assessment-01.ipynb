# %% [markdown]
# ## Download the image

# %%
# !wget https://upload.wikimedia.org/wikipedia/commons/thumb/e/ec/Mona_Lisa%2C_by_Leonardo_da_Vinci%2C_from_C2RMF_retouched.jpg/1280px-Mona_Lisa%2C_by_Leonardo_da_Vinci%2C_from_C2RMF_retouched.jpg -O image.jpg
# Out:
# --2023-02-10 11:49:31--  https://upload.wikimedia.org/wikipedia/commons/thumb/e/ec/Mona_Lisa%2C_by_Leonardo_da_Vinci%2C_from_C2RMF_retouched.jpg/1280px-Mona_Lisa%2C_by_Leonardo_da_Vinci%2C_from_C2RMF_retouched.jpg
# Resolving upload.wikimedia.org (upload.wikimedia.org)... 91.198.174.208
# Connecting to upload.wikimedia.org (upload.wikimedia.org)|91.198.174.208|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 977350 (954K) [image/jpeg]
# Saving to: 'image.jpg'
#
# image.jpg           100%[===================>] 954.44K  1.15MB/s    in 0.8s
#
# 2023-02-10 11:49:32 (1.15 MB/s) - 'image.jpg' saved [977350/977350]

# %% [markdown]
# ## Display image

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from PIL import Image
img = np.array(Image.open('image.jpg'))
imgplot = plt.imshow(img)
plt.show()

# %% [markdown]
# ## Display modified image

# %%
(rows, cols, _) = img.shape
img.setflags(write=1)
img[:30, cols-30:] = [0, 0, 0]
plt.imshow(img)
plt.show()
